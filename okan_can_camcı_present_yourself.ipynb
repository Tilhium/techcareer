# %%
name="Okan Can"
surname="Camcı"
age=22
university="Beykoz University"
department="Computer Engineering"
print(f"My name is {name} surname is {surname},I'm {age} years old. And I'm a {department} student at {university}")
# Out:
# My name is Okan Can surname is Camcı,I'm 22 years old. And I'm a Computer Engineering student at Beykoz University
